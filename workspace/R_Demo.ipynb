# %% [markdown]
# #

# %%
library(reticulate)
library(ggplot2)
fr <- import("psifr.fr")
# Out:
# Warning message in normalizePath(path.expand(path), winslash, mustWork):
# "path[1]="C:\Users\gunnj\.conda\envs\r-reticulate/python.exe": The system cannot find the file specified"
# Warning message in normalizePath(path.expand(path), winslash, mustWork):
# "path[1]="C:\Users\gunnj\.conda\envs\r-reticulate/python.exe": The system cannot find the file specified"

# %%
data <- read.csv("../data/psifr_sbs.csv")
merged<- fr$merge_free_recall(data)
spc <- fr$spc(merged)

# %%
spc
# Out:
#     subject input recall
# 1   0        1    0.6666667
# 2   0        2    0.6111111
# 3   0        3    0.6666667
# 4   0        4    0.7222222
# 5   0        5    0.5000000
# 6   0        6    0.5000000
# 7   0        7    0.4444444
# 8   0        8    0.3888889
# 9   0        9    0.1666667
# 10  0       10    0.6111111
# 11  0       11    0.4444444
# 12  0       12    0.5555556
# 13  0       13    0.3888889
# 14  0       14    0.3888889
# 15  0       15    0.5555556
# 16  0       16    0.5555556
# 17  0       17    0.5000000
# 18  0       18    0.5555556
# 19  0       19    0.4444444
# 20  0       20    0.4444444
# 21  0       21    0.3333333
# 22  0       22    0.7222222
# 23  0       23    0.2777778
# 24  0       24    0.5000000
# 25  0       25    0.4444444
# 26  0       26    0.3888889
# 27  0       27    0.3333333
# 28  0       28    0.1333333
# 29  0       29    0.6000000
# 30  0       30    0.4666667
# ... ...     ...   ...
# 917 21      14    0.55555556
# ...

# %%
ggplot(data=spc, aes(x=input, y=recall)) +
  geom_line()
# Out:
# plot without title

# %%
package.install('ggplot2')
# Out:
# Error in package.install("ggplot2"): could not find function "package.install"
# Traceback:
